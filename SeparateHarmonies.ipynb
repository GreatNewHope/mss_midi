# %% [markdown]
# Colab execution:
# Add the following environment variables to every make command
# `PACKAGE_MANAGER=pip PYTHON=python`

# %%
# TL;DR: Falling Slowly — isolate all vocals, then split the duet.
#!make run-duet PACKAGE_MANAGER=pip PYTHON=python INPUT="songs/FallingSlowly/01 - Falling Slowly.flac" OUTPUT_DIR=run_falling_slowly DEVICE=cuda
# !make run-duet INPUT="songs/FallingSlowly/01 - Falling Slowly.flac" OUTPUT_DIR=run_falling_slowly DEVICE=cpu
# Out:
# Already up to date.
# Already up to date.
# Already up to date.
# uv run python patch_unmixx_requirements.py "third_party/unmixx"
# Removed UNMIXX's private editable tssep requirement from third_party/unmixx/requirements.txt.
# Replaced UNMIXX's Asteroid-only pad helper in third_party/unmixx/look2hear/models/unmixx_model.py.
# uv sync --upgrade --inexact
# Resolved 108 packages in 3.34s
# Checked 77 packages in 8ms
# Skipping UNMIXX's full frozen requirements export; using the runtime dependencies already installed by this project.
# Skipping Music-Source-Separation-Training's full training requirements; using the runtime dependencies already installed by this project.
# uv pip install --upgrade -r requirements.txt
# Resolved 50 packages in 1.68s
# Checked 50 packages in 5ms
# uv run python pipeline.py "songs/FallingSlowly/01 - Falling Slowly.flac" \
# 		--mode duet \
# 		--unmixx-repo "third_party/unmixx" \
# 		--device "cpu" \
# 		--unmixx-chunk-seconds "4" \
# 		--unmixx-overlap-seconds "1" \
# 		--output-dir "run_falling_slowly"
# [Stage 1] Isolate all vocals with melband-roformer-kim-vocals
# + ffmpeg -y -hide_banner -loglevel error -i /Users/O000142/ProjectsPersonal/musica/choir_separator_project/songs/FallingSlowly/01 - Falling Slowly.flac -ar 44100 -ac 2 -c:a pcm_f32le /Users/O000142/ProjectsPersonal/musica/choir_separator_project/run_falling_slowly/stage1_all_vocals/input_44k_stereo.wav
# + /Users/O000142/ProjectsPersonal/musica/choir_separator_project/.venv/bin/melband-roformer-infer --input_folder /var/folders/jm/mc7b8v9x7w912wk1kmk0z7b00000gp/T/melband_input_mivuwvpc --store_dir /Users/O000142/ProjectsPersonal/musica/choir_separator_project/run_falling_slowly/stage1_all_vocals --model melband-roformer-kim-vocals --device cpu
# /Users/O000142/ProjectsPersonal/musica/choir_separator_project/.venv/lib/python3.12/site-packages/torch/functional.py:680: UserWarning: A window was not provided. A rectangular window will be applied,which is known to cause spectral leakage. Other windows such as torch.hann_window or torch.hamming_window are recommended to reduce spectral leakage.To suppress this warning and use a rectangular window, explicitly set `window=torch.ones(n_fft, device=<device>)`. (Triggered internally at /Users/runner/work/pytorch/pytorch/aten/src/ATen/native/SpectralOps.cpp:841.)
#   return _VF.stft(  # type: ignore[attr-defined]
# Using model weights: /Users/O000142/.cache/melband-roformer-infer/melband-roformer-kim-vocals/MelBandRoformer.ckpt
# Total tracks found: 1
# Tracks:   0%|                                         | 0/1 [00:00<?, ?track/s]
# Processing track 1/1: input_44k_stereo.wav
# /Users/O000142/ProjectsPersonal/musica/choir_separator_project/.venv/lib/python3.12/site-packages/mel_band_roformer/utils.py:86: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# /Users/O000142/ProjectsPersonal/musica/choir_separator_project/.venv/lib/python3.12/site-packages/torch/cuda/amp/autocast_mode.py:54: UserWarning: CUDA is not available or torch_xla is imported. Disabling autocast.
#   super().__init__(
# /Users/O000142/.local/share/uv/python/cpython-3.12.13-macos-aarch64-none/lib/python3.12/contextlib.py:105: FutureWarning: `torch.backends.cuda.sdp_kernel()` is deprecated. In the future, this context manager will be removed. Please see `torch.nn.attention.sdpa_kernel()` for the new context manager, with updated signature.
#   self.gen = func(*args, **kwds)
# Estimated total processing time for this track: 424.83 seconds
# Estimated time remaining: 185.86 seconds

# %%
# Optional: recreate Bad Idea's backing-vocal stem from the complete song.
# !make run-full PACKAGE_MANAGER=pip PYTHON=python INPUT="songs/BadIdea/12 Bad Idea.mp3" OUTPUT_DIR=run_bad_idea DEVICE=cuda

# %%
# TL;DR: Bad Idea — split an existing Mega53 backing-vocal stem into choir-part estimates.
# !make run-choir-parts PACKAGE_MANAGER=pip PYTHON=python CHOIR_INPUT="songs/BadIdea/01_choir_backing.wav" CHOIR_OUTPUT_DIR=songs/BadIdea/choir_parts CHOIR_DEVICE=cuda

# %%
# TL;DR: GAME Large — MIDI for Falling Slowly's isolated lead singers.
# !make run-midi PACKAGE_MANAGER=pip PYTHON=python MIDI_INPUT=run_falling_slowly/final MIDI_GLOB='0[3-4]_singer_*.wav' MIDI_OUTPUT_DIR=run_falling_slowly/midi MIDI_LANGUAGE=en

# %%
# TL;DR: GAME Large — one MIDI track for each pitched Bad Idea choir-part estimate.
# The glob deliberately skips 01_vocal_percussion.wav.
# !make run-midi PACKAGE_MANAGER=pip PYTHON=python MIDI_INPUT=songs/BadIdea/choir_parts MIDI_GLOB='0[2-6]_*.wav' MIDI_OUTPUT_DIR=songs/BadIdea/choir_midi

# %%
# Optional fallback: a single polyphonic MIDI from an unseparated choir mix (not SATB-labelled).
# !make run-polyphonic-choir-midi PACKAGE_MANAGER=pip PYTHON=python MIDI_INPUT=songs/BadIdea/01_choir_backing.wav MIDI_OUTPUT_DIR=songs/BadIdea/choir_polyphonic_midi
